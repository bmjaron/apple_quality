# %% [markdown]
# <a href="https://colab.research.google.com/github/bmjaron/apple_quality/blob/main/index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
username = input("Enter username:")

key = input("Enter API key:")
# Out:
# Enter username:
# Enter API key:

# %%
import json
import os
from pathlib import Path

# your api key
api_key = {
'username':f"{username}" ,
'key':f"{key}"}

# uses pathlib Path
kaggle_path = Path('/root/.kaggle')
os.makedirs(kaggle_path, exist_ok=True)

# opens file and dumps python dict to json object
with open (kaggle_path/'kaggle.json', 'w') as handl:
    json.dump(api_key,handl)

os.chmod(kaggle_path/'kaggle.json', 600)

# %%
import kaggle

# %%
# !kaggle datasets download -d nelgiriyewithana/apple-quality
# Out:
# ...
#   0% 0.00/170k [00:00<?, ?B/s]
# 100% 170k/170k [00:00<00:00, 84.6MB/s]

# %%
# !unzip /content/apple-quality.zip
# Out:
# Archive:  /content/apple-quality.zip
#   inflating: apple_quality.csv

# %%
#Load .json file
df = pd.read_csv("/content/apple_quality.csv")
df.head()
# Out:
#    A_id      Size    Weight  Sweetness  Crunchiness  Juiciness  Ripeness  \
# 0   0.0 -3.970049 -2.512336   5.346330    -1.012009   1.844900  0.329840
# 1   1.0 -1.195217 -2.839257   3.664059     1.588232   0.853286  0.867530
# 2   2.0 -0.292024 -1.351282  -1.738429    -0.342616   2.838636 -0.038033
# 3   3.0 -0.657196 -2.271627   1.324874    -0.097875   3.637970 -3.413761
# 4   4.0  1.364217 -1.296612  -0.384658    -0.553006   3.030874 -1.303849
#
#         Acidity Quality
# 0  -0.491590483    good
# 1  -0.722809367    good
# 2   2.621636473     bad
# 3   0.790723217    good
# 4   0.501984036    good
